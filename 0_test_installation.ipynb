# %%
from langgraph.graph import StateGraph

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

response = llm.invoke("Explain LangChain in simple terms")
print(response.content)
# Out:
# Imagine you have a super-smart, creative brain – that's your Large Language Model (LLM) like ChatGPT. This brain is amazing at talking, writing, and understanding things.
#
# **The Problem:** This super-smart brain is stuck in a box.
# *   It can't remember what you said five minutes ago.
# *   It can't go look things up on the internet in real-time.
# *   It can't use a calculator, check the weather, or send an email.
# *   It struggles with really complex tasks that require multiple steps and different tools.
#
# **LangChain is like giving that super-smart brain a body, a memory, and a toolbox.**
#
# Here's what it lets your LLM do:
#
# 1.  **Memory:** It helps the LLM remember past parts of your conversation. This makes chatbots feel much more natural and personal, as they can refer back to earlier things you've discussed.
#     *   *Analogy:* Like giving the brain a notebook to jot down important details from your chat.
#
# 2.  **Tools:** It allows the LLM to use external tools and services.
#     *   **Web Search:** "Hey brain, go look up the current news on X."
#     *   **Calculators:** "Brain, what's 1234 * 5678?"
#     *   **APIs:** "Brain, go check the weather in London," or "Brain, add this event to my calendar."
#     *   *Analogy:* Like giving the brain a smartphone with apps, a calculator, and access to the internet.
#
# 3.  **Chains/Agents (Planning & Reasoning):** This is where it gets really powerful. LangChain helps the LLM break down complex problems into smaller, manageable steps and then execute those steps using its memory and tools in the right order.
#     *   *Example:* You ask, "What's the capital of France, and how many people live there according to the latest census?"
#         *   LangChain helps the LLM first figure out: "Okay, I need to look up the capital of France."
#         *   Then: "Now I need to look up the population of that city."
#         *   Finally: "Combine these two pieces of information and answer the user."
#     *   *Analogy:* Like giving the brain a project manager who can delegate tasks, use tools, and follow a plan to achieve a goal.
#
# **In Simple Terms:**
#
# LangChain is a **framework that makes it easier to build powerful applications using large language models (LLMs)**. It takes a brilliant but isolated LLM and gives it the ability to:
# *   **Remember** past interactions.
# *   **Use external tools** (like web search, calculators, or custom software).
# *   **Plan and execute multi-step tasks** by combining its knowledge, memory, and tools.
#
# It essentially transforms a powerful text generator into a versatile, intelligent agent that can interact with the real world and perform complex actions.
