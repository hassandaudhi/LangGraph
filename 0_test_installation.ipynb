# %%
from langgraph.graph import StateGraph

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

response = llm.invoke("Explain LangChain in simple terms")
print(response.content)
# Out:
# Imagine you have a super-smart, text-generating robot (that's the **Large Language Model** like ChatGPT). This robot is amazing at understanding and creating human-like text.
#
# However, this robot has some limitations:
#
# 1.  **It only knows what it was trained on:** It doesn't know about real-time events, your company's internal documents, or specific data from yesterday.
# 2.  **It can't *do* anything:** It can't search the internet, send an email, run code, or interact with other software.
# 3.  **It forgets things quickly:** Each conversation is usually a blank slate.
#
# **LangChain is like a toolkit or a "helper" that gives this super-smart robot extra capabilities, letting it become much more useful.**
#
# Think of LangChain as:
#
# *   **Giving the robot "eyes":** It allows the robot to look up new information from the internet, your company's databases, PDFs, etc., and use that information in its answers.
# *   **Giving the robot "hands":** It allows the robot to use tools – like a search engine, a calculator, a calendar app, or even code interpreters – to perform actions and get more precise results.
# *   **Giving the robot "memory":** It helps the robot remember past parts of a conversation so it can hold more natural and continuous dialogues.
# *   **Giving the robot "instructions":** It helps you chain together multiple steps (e.g., "first, search for this; then, summarize that; finally, answer the user's question").
#
# **In simple terms:**
#
# LangChain is a framework that makes it easier for developers to build powerful applications *around* Large Language Models. It helps you connect LLMs to external data sources, allow them to use tools, manage conversation history, and orchestrate complex tasks, turning a smart text generator into a much more capable and interactive AI assistant.
#
# **Example:**
# Instead of just asking ChatGPT "What's the weather?", with LangChain, you could build an app where your LLM-powered assistant could:
# 1.  **Look up** your current location.
# 2.  **Search** a real-time weather API for that location.
# 3.  **Summarize** the forecast for you.
# 4.  **Remember** if you asked about the weather yesterday.
# 5.  **Suggest** "Should I also check your commute for tomorrow?"
#
# LangChain provides the building blocks to make all those steps happen seamlessly.
